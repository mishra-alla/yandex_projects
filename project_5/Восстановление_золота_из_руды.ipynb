# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span><strong>Описание данных</strong></a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Откройте-файлы-и-изучите-их" data-toc-modified-id="Откройте-файлы-и-изучите-их-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span><strong>Откройте файлы и изучите их</strong></a></span></li><li><span><a href="#Проверим,-что-эффективность-обогащения-рассчитана-правильно" data-toc-modified-id="Проверим,-что-эффективность-обогащения-рассчитана-правильно-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span><strong>Проверим, что эффективность обогащения рассчитана правильно</strong></a></span></li><li><span><a href="#Проанализируйте-признаки,-недоступные-в-тестовой-выборке" data-toc-modified-id="Проанализируйте-признаки,-недоступные-в-тестовой-выборке-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span><strong>Проанализируйте признаки, недоступные в тестовой выборке</strong></a></span></li><li><span><a href="#Проведите-предобработку-данных" data-toc-modified-id="Проведите-предобработку-данных-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span><strong>Проведите предобработку данных</strong></a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Как-меняется-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки." data-toc-modified-id="Как-меняется-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span><strong>Как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки.</strong></a></span></li><li><span><a href="#Сравним-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках." data-toc-modified-id="Сравним-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span><strong>Сравним распределения размеров гранул сырья на обучающей и тестовой выборках.</strong></a></span></li><li><span><a href="#Исследуем-суммарную-концентрацию-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах." data-toc-modified-id="Исследуем-суммарную-концентрацию-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span><strong>Исследуем суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.</strong></a></span></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Напишите-функцию-для-вычисления-итоговой-sMAPE." data-toc-modified-id="Напишите-функцию-для-вычисления-итоговой-sMAPE.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span><strong>Напишите функцию для вычисления итоговой sMAPE.</strong></a></span></li><li><span><a href="#Обучите-разные-модели-и-оцените-их-качество-кросс-валидацией" data-toc-modified-id="Обучите-разные-модели-и-оцените-их-качество-кросс-валидацией-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span><strong>Обучите разные модели и оцените их качество кросс-валидацией</strong></a></span></li></ul></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-4"><span class="toc-item-num">4&nbsp;&nbsp;</span><strong>Вывод:</strong></a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.

# %% [markdown]
# ### **Описание данных**
#
# - Данные находятся в трёх файлах:
#  - `gold_recovery_train_new.csv` — обучающая выборка;
#  - `gold_recovery_test_new.csv` — тестовая выборка;
#  - `gold_recovery_full_new.csv` — исходные данные.
#
# - Данные индексируются датой и временем получения информации (признак `date`).
# - Соседние по времени параметры часто похожи.
# - Некоторые параметры недоступны, потому что замеряются и/или рассчитываются значительно позже. Из-за этого в тестовой выборке отсутствуют некоторые признаки, которые могут быть в обучающей.
# - Также в тестовом наборе нет целевых признаков.
# Исходный датасет содержит обучающую и тестовую выборки со всеми признаками.
#
# - В вашем распоряжении сырые данные: их просто выгрузили из хранилища.
#  > Прежде чем приступить к построению модели, проверьте по нашей инструкции их на корректность.
#
# **Технологический процесс**
# - *Rougher feed* — исходное сырье
# - *Rougher additions (или reagent additions)* — флотационные реагенты: Xanthate, Sulphate, Depressant
#
# - *Xanthate* *** — ксантогенат (промотер, или активатор флотации);
# - *Sulphate* — сульфат (на данном производстве сульфид натрия);
# - *Depressant* — депрессант (силикат натрия).
# - *Rougher process (англ. «грубый процесс»)* — флотация
# - *Rougher tails* — отвальные хвосты
# - *Float banks* — флотационная установка
# - *Cleaner process* — очистка
# - *Rougher Au* — черновой концентрат золота
# - *Final Au* — финальный концентрат золота
#
# **Параметры этапов**
# - *air amount* — объём воздуха
# - *fluid levels* — уровень жидкости
# - *feed size* — размер гранул сырья
# - *feed rate* — скорость подачи
#
# > именование признаков должно быть такое:
#
#   ``[этап].[тип_параметра].[название_параметра]
#   Пример: rougher.input.feed_ag ``
#
#
# Возможные значения для блока [этап]:
# - *rougher* — флотация
# - *primary_cleaner* — первичная очистка
# - *secondary_cleaner* — вторичная очистка
# - *final* — финальные характеристики
#
# Возможные значения для блока [тип_параметра]:
# - *input* — параметры сырья
# - *output* — параметры продукта
# - *state* — параметры, характеризующие текущее состояние этапа
# - *calculation* — расчётные характеристики

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Метрика качества**
#
# Для решения задачи введём новую метрику качества — **sMAPE** (англ. `Symmetric Mean Absolute Percentage Error`, «симметричное среднее абсолютное процентное отклонение»).
#
# > Она похожа на **MAE**, но выражается не в абсолютных величинах, а в относительных. **Почему симметричная? Она одинаково учитывает масштаб и целевого признака, и предсказания.**
#
# Метрика **sMAPE** вычисляется так:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Обозначения:**
# - **N** - количество объектов в выборке.
# - Значение целевого признака для объекта с порядковым номером `i` в выборке, на которой измеряется качество.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Значение предсказания для объекта с порядковым номером `i`, например, в тестовой выборке.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Суммирование по всем объектам выборки (`i` меняется от `1 до N`).
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Чтобы спрогнозировать сразу две величины:**
# - эффективность обогащения чернового концентрата `rougher.output.recovery`;
# - эффективность обогащения финального концентрата `final.output.recovery`.
#
# Складываем эти две величины:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Подготовка данных

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.dummy import DummyRegressor
from sklearn.metrics import make_scorer,r2_score,mean_absolute_error,  mean_squared_error
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import roc_auc_score, roc_curve, confusion_matrix
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from numpy.random import RandomState
from sklearn.utils import shuffle

import seaborn as sns
import matplotlib.pyplot as plt
from joblib import dump

# %% [markdown]
# ### **Откройте файлы и изучите их**

# %%
import warnings
warnings.filterwarnings('ignore')

try:
    data_full=pd.read_csv('/content/gold_recovery_full_new.csv', sep=',')
    data_train=pd.read_csv('/content/gold_recovery_train_new.csv', sep=',')
    data_test=pd.read_csv('/content/gold_recovery_test_new.csv', sep=',')
except:
    data_full=pd.read_csv('/datasets/gold_recovery_full_new.csv', sep=',')
    data_train=pd.read_csv('/datasets/gold_recovery_train_new.csv', sep=',')
    data_test=pd.read_csv('/datasets/gold_recovery_test_new.csv', sep=',')

# Приведем все даенные в читаемый формат
pd.options.display.float_format = '{:,.2f}'.format

# %%
#напишем функию для исследования данных
def research(data, name, silent):
    print(f'Размер данных:      {data.shape}')
    print(f'Количество явных дубликатов: {data.duplicated().sum()}')
    print(f'Наличие пропусков:           {data.isna().sum().sum()}')
    print('Пропущенные данные (в процентном соотношении):')
    print(round(data.isna().mean()*100).sort_values(ascending=False).head(13))
    print(f'\nПроверка структуры данных {name}:')
    print()
    data.info()
    print(f'\nПроверка на выбросы данных {name}:')
    if not silent:
        data.hist(linewidth=2, histtype='step', figsize=(40, 35))
        plt.show()
#    print(f'\nКорреляция данных {name}')
#    display(data.corr()\
#            .style\
#            .background_gradient(cmap='Pastel2', low= 0, high = 1, axis = 1, subset = None))
    display(data.sample(5))
    display(data.describe())

# %%
research(data_full, 'исходных данных', silent=True)
# Out:
# Размер данных:      (19439, 87)
# Количество явных дубликатов: 0
# Наличие пропусков:           4481
# Пропущенные данные (в процентном соотношении):
# secondary_cleaner.output.tail_sol          9.00
# rougher.input.floatbank11_xanthate         2.00
# rougher.state.floatbank10_e_air            2.00
# primary_cleaner.output.concentrate_sol     2.00
# primary_cleaner.input.xanthate             1.00
# rougher.input.feed_sol                     1.00
# rougher.input.feed_size                    1.00
# rougher.input.feed_pb                      1.00
# primary_cleaner.output.concentrate_pb      1.00
# secondary_cleaner.state.floatbank2_a_air   1.00
# final.output.tail_pb                       1.00
# final.output.concentrate_sol               1.00
# secondary_cleaner.state.floatbank4_b_air   0.00
# dtype: float64
#
# Проверка структуры данных исходных данных:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
# ...

# %%
research(data_train, 'тренировочной выборки', silent=True)
# Out:
# Размер данных:      (14149, 87)
# Количество явных дубликатов: 0
# Наличие пропусков:           4100
# Пропущенные данные (в процентном соотношении):
# secondary_cleaner.output.tail_sol          11.00
# rougher.input.floatbank11_xanthate          3.00
# rougher.state.floatbank10_e_air             3.00
# primary_cleaner.output.concentrate_sol      2.00
# secondary_cleaner.state.floatbank2_a_air    2.00
# final.output.tail_pb                        1.00
# final.output.concentrate_sol                1.00
# primary_cleaner.input.xanthate              1.00
# primary_cleaner.output.concentrate_pb       1.00
# rougher.input.feed_pb                       1.00
# rougher.input.feed_sol                      1.00
# rougher.input.feed_size                     1.00
# secondary_cleaner.state.floatbank5_b_air    0.00
# dtype: float64
#
# Проверка структуры данных тренировочной выборки:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# ...

# %%
research(data_test, 'тестовой выборки', silent=True)
# Out:
# Размер данных:      (5290, 53)
# Количество явных дубликатов: 0
# Наличие пропусков:           90
# Пропущенные данные (в процентном соотношении):
# date                                         0.00
# rougher.state.floatbank10_c_air              0.00
# rougher.state.floatbank10_d_air              0.00
# rougher.state.floatbank10_d_level            0.00
# rougher.state.floatbank10_e_air              0.00
# rougher.state.floatbank10_e_level            0.00
# rougher.state.floatbank10_f_air              0.00
# rougher.state.floatbank10_f_level            0.00
# secondary_cleaner.state.floatbank2_a_air     0.00
# secondary_cleaner.state.floatbank2_a_level   0.00
# secondary_cleaner.state.floatbank2_b_air     0.00
# secondary_cleaner.state.floatbank2_b_level   0.00
# secondary_cleaner.state.floatbank3_a_air     0.00
# dtype: float64
#
# Проверка структуры данных тестовой выборки:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5290 entries, 0 to 5289
# ...

# %%
#data_full.hist(linewidth=2, histtype='step', figsize=(40, 35))
#plt.show()

# %% [markdown]
# **Вывод:**
# - Иссследуем три выборки data_full, data_train, data_test - размер у них разный (как в принципе и должно быть)
# - Дубликаты во всех датасетах отсутствуют
# - Видно наличие пропусках в данных, больше всего их в тренировочной выборке - 41007. В дальнейшем поработаем с ними.
# - Гистограммы данных в исходных данных в целом показывают нормальное распределение.
# -  В test отсутсвтуют целевые признаки.
#
# В целом данные друг другу соответствуют.

# %% [markdown]
# ### **Проверим, что эффективность обогащения рассчитана правильно**
# - Вычисляем её на обучающей выборке для признака `rougher.output.recovery. `
# - Найдем **MAE** между нашими расчётами и значением признака.
#
# **Расчёт эффективности**:
#
# Нам нужно смоделировать процесс восстановления золота из золотосодержащей руды.
# > Для прогноза коэффициента нужно найти долю золота в концентратах и хвостах. Причём важен не только финальный продукт, но и черновой концентрат.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# где:
#
# - С - доля золота концентрате после фильтрации/очитски
# - F - доля золота в сырье/концентрате до флотации/очистки
# - T - доля золота в отвальных хвостах после фильтрации/очистки
#
# Принимая во внимание условие задачи, нам нужен этап флотации, а значит:
# - C - это `rougher.output.concentrate_au`
# - F - это `rougher.input.feed_au`
# - T - это `rougher.output.tail_au`
#
# Значение нужного нам признака - `rougher.output.recovery`

# %%
#Вычислим эффективность обогащения на обучающей выборке
C = data_train['rougher.output.concentrate_au']
F = data_train['rougher.input.feed_au']
T = data_train['rougher.output.tail_au']
#создадим новый столбец для наших вычислений
data_train['recovery'] = (((C*(F-T))/(F*(C-T)))*100)
data_train['recovery'].mean()
# Out:
# 82.70450164550293

# %%
#сравним с признаком rougher.output.recovery
data_train['rougher.output.recovery'].mean()
# Out:
# 82.70450164550293

# %%
print('Средняя абсолютная ошибка (MAE) между нашими расчётами и значением признака =', mean_absolute_error(data_train['recovery'], data_train['rougher.output.recovery']))
# Out:
# Средняя абсолютная ошибка (MAE) между нашими расчётами и значением признака = 9.73512347450521e-15

# %%
#Теперь удалим наш столбец за ненадобностью
data_train.drop('recovery', axis=1, inplace=True)

# %% [markdown]
# **Вывод:**
#
# В результате расчетов видим, что величина средней абсолютной ошибки MAE практически равна нулю (очень сильно к нему стремиться).
# > Следовательно величина обогащения, представленная в данных рассчитана правильно.

# %% [markdown]
# ### **Проанализируйте признаки, недоступные в тестовой выборке**
# Что это за параметры? К какому типу относятся?

# %%
data_nottest = set(data_train.columns) - set(data_test.columns)
print(f'Количество отсутствующих признаков в тестовой выборке - {len(data_nottest)}')
data_nottest
# Out:
# Количество отсутствующих признаков в тестовой выборке - 34
# {'final.output.concentrate_ag',
#  'final.output.concentrate_au',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_au',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_au',
#  'rougher.output.concentrate_pb',
# ...

# %%
dict_values_name = {'final': 'финальные характеристики',
                           'primary_cleaner': 'первичная очистка',
                           'secondary_cleaner': 'вторичная очистка',
                           'input': 'параметры сырья',
                           'output': 'параметры продукта',
                           'rougher': 'флотация',
                           'state': 'параметры, характеризующие текущее состояние этапа',
                           'calculation': 'расчётные характеристики'}

# %% [markdown]
# **Вывод:**
# - Количество отсутствующих признаков в тестовой выборке - 34;
# - В тестовой выборке прежде всего отсутствуют целевые признаки `rougher.output.recovery` и `final.output.recovery` - они нам могут понадобиться для расчета метрики качества. Поэтому планирую их добавить в в выборку.
# - В тестовой выборке отсутствует большое количество значений, касающихся флотации, параметров продукта, меньше всего отсутствует информация о расчетных характеристиках.
# - таким образом мы видим, что отсутствующие признаки преимущественно относятся к вторичным стадиям обогащения: параметры продуктов, а не сырья.
# > Отсутствие признаков скорее всего можно обьяснить тем, что они замеряются и рассчитываются значительно позже (по условию задачи).

# %% [markdown]
# ### **Проведите предобработку данных**

# %%
#Заполним отсутствующие значения в  исходных данных, тренировочной и тестовой выборках помощью функции ffill
#Проверим на наличие пропусков после обработки
data_full = data_full.ffill(axis=0)
data_train = data_train.ffill(axis=0)
data_test = data_test.ffill(axis=0)
print(f'Количество пропусков:')
print(f'- в исходном датасете = {data_full.isna().sum().sum()}')
print(f'- в тренировочном датасете = {data_train.isna().sum().sum()}')
print(f'- в тестовом датасете = {data_test.isna().sum().sum()}')
# Out:
# Количество пропусков:
# - в исходном датасете = 0
# - в тренировочном датасете = 0
# - в тестовом датасете = 0

# %%
#Добавим недостающие данные в data_test
data_test = data_test.merge(data_full[['final.output.recovery', 'rougher.output.recovery', 'date']], how='left', on='date')

# %%
#удалим столбец data - как неинформативный для дальнейшего построения нашей модели
data_train = data_train.drop('date', axis=1)
data_test = data_test.drop('date', axis=1)

# %%
print(f'\nРазмер тестовой выборки: {data_test.shape}')
print(f'Размер тренировочной выборки: {data_train.shape}')
#data_train.info()
data_test.info()
# Out:
# Размер тестовой выборки: (5290, 54)
# Размер тренировочной выборки: (14149, 86)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5290 entries, 0 to 5289
# Data columns (total 54 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   primary_cleaner.input.sulfate               5290 non-null   float64
#  1   primary_cleaner.input.depressant            5290 non-null   float64
#  2   primary_cleaner.input.feed_size             5290 non-null   float64
#  3   primary_cleaner.input.xanthate              5290 non-null   float64
#  4   primary_cleaner.state.floatbank8_a_air      5290 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_level    5290 non-null   float64
#  6   primary_cleaner.state.floatbank8_b_air      5290 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_level    5290 non-null   float64
# ...

# %% [markdown]
# **Вывод:**
# - заменила отсутствующие значения данными из строк выше.
# - удалила неинформативные для дальнейшей работы столбцы.
# - Добавила в тестовую выборку информацию по целевым признакам `rougher.output.recovery` и `final.output.recovery`

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### **Как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки.**

# %%
def gragh(data_train, metal, name_metal):
    plt.figure(figsize=[20, 10])
    #plt.subplots_adjust(top=0.94, wspace=0.2, hspace=0.3)
    #plt.suptitle('График концентрации металлов на различных этапах очистки', fontsize=15)
    plt.title(f'Гистограмма распределения концентрации {name_metal} на различных этапах очистки', fontsize=18)
    sns.set_style('whitegrid')
    sns.histplot(data_train[f'rougher.input.feed_{metal}'], color="deepskyblue", label='Сырье', alpha=0.8)#, kde=False, kde=False, kde=False,kde=False
    sns.histplot(data_train[f'rougher.output.concentrate_{metal}'], color="salmon", label=f'Концентрация {name_metal} после флотации', alpha=0.8)
    sns.histplot(data_train[f'primary_cleaner.output.concentrate_{metal}'], color="seagreen", label=f'Концентрация {name_metal} после первичной очистки', alpha=0.8)
    sns.histplot(data_train[f'final.output.concentrate_{metal}'], color="gold", label=f'Финальная концетрация {name_metal}', alpha=0.8)
    plt.xlabel(f'Концентрация {name_metal}', fontsize=14)
    plt.ylabel(f'Количество наблюдений', fontsize=14)
    plt.legend(loc='upper left', fontsize='large')

# %%
gragh(data_train, 'au', 'золота (Au)')

# %%
gragh(data_train, 'ag', 'серебра (Ag)')

# %%
gragh(data_train, 'pb', 'свинца (Pb)')

# %% [markdown]
# Вывод:
# - наблюдается в целом нормальное распределение по всем элементам;
# - на диаграммах явно виден выброс на всех выборках - в дальнейшем более детально рассмотрим этот момент

# %% [markdown]
# ### **Сравним распределения размеров гранул сырья на обучающей и тестовой выборках.**
# > Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.

# %%
#Визуализируем наши данные
def feed_size(data_train, data_test, state, name_state, x_lim):
    print(f'Статистические данные о распределении значений в тренировочной выборке на {name_state}:')
    display(data_train[f'{state}.input.feed_size'].describe())
    print(f'\nСтатистические данные о распределении значений в тестовой выборке на {name_state}:')
    display(data_test[f'{state}.input.feed_size'].describe())
    plt.figure(figsize=(15, 8))
    sns.kdeplot(data_train[f'{state}.input.feed_size'], fill=True, label=f'train: размеры гранул сырья на {name_state}', alpha=0.6, shade=True)
    sns.kdeplot(data_test[f'{state}.input.feed_size'], fill=True, label=f'test: размеры гранул сырья на {name_state}', alpha=0.6, shade=True)
    plt.xlim([0, x_lim])
    plt.xlabel('Размер гранул сырья')
    plt.ylabel(f'Плотность ядра распределения вероятности непрерывной величины')
    plt.legend(loc='upper right')
    plt.title(f'Плотность ядра распределения размера гранул сырья \n тренировочной и тестовой выборок на {name_state}', fontsize=18)
    plt.show()
    plt.subplots(figsize=(15, 5))
    plt.title(f'Диаграмма рассеяния размера гранул сырья на тренировочной и тестовой выборке на {name_state}')
    sns.boxplot(x=data_train[f'{state}.input.feed_size'], palette='pastel', data=data_train[f'{state}.input.feed_size'])
    #plt.show()
    #plt.subplots(figsize=(10, 2))
    #plt.title("Диаграмма рассеяния размера гранул сырья на тестовой выборке")
    sns.boxplot(x=data_test[f'{state}.input.feed_size'], palette='Oranges', data=data_test[f'{state}.input.feed_size'])
    #sns.violinplot(x=data_train[f'{state}.input.feed_size'], palette='pastel', data=data_train[f'{state}.input.feed_size'], alpha=0.6)
    #sns.violinplot(x=data_test[f'{state}.input.feed_size'], palette='Oranges', data=data_train[f'{state}.input.feed_size'], alpha=0.4)
    plt.show()

# %%
feed_size(data_train, data_test, 'rougher', 'стадии флотации', 170)
# Out:
# Статистические данные о распределении значений в тренировочной выборке на стадии флотации:
# count   14,149.00
# mean        60.24
# std         23.01
# min          9.66
# 25%         48.97
# 50%         55.27
# 75%         66.01
# max        484.97
# Name: rougher.input.feed_size, dtype: float64
# Статистические данные о распределении значений в тестовой выборке на стадии флотации:
# count   5,290.00
# mean       55.95
# std        19.08
# min         0.05
# 25%        43.91
# 50%        50.85
# 75%        62.45
# max       392.49
# Name: rougher.input.feed_size, dtype: float64

# %%
feed_size(data_train, data_test, 'primary_cleaner', 'стадии первичной очистки', 14)
# Out:
# Статистические данные о распределении значений в тренировочной выборке на стадии первичной очистки:
# count   14,149.00
# mean         7.32
# std          0.61
# min          1.08
# 25%          6.96
# 50%          7.29
# 75%          7.70
# max         10.47
# Name: primary_cleaner.input.feed_size, dtype: float64
# Статистические данные о распределении значений в тестовой выборке на стадии первичной очистки:
# count   5,290.00
# mean        7.27
# std         0.61
# min         5.65
# 25%         6.89
# 50%         7.25
# 75%         7.60
# max        15.50
# Name: primary_cleaner.input.feed_size, dtype: float64

# %%
#Исследуем распределение гранул сырья на стадии флотации методом Колмогорова-Смирнова на одинаковость
from scipy import stats
from scipy.stats import kstest, ks_2samp
ks_2samp(data_train['rougher.input.feed_size'], data_test['rougher.input.feed_size'])
# Out:
# KstestResult(statistic=0.2502993057549405, pvalue=5.1997046130555955e-213)

# %%
#Исследуем распределение  гранул сырьяна стадии первичной очистки методом Колмогорова-Смирнова на одинаковость
ks_2samp(data_train['primary_cleaner.input.feed_size'], data_test['primary_cleaner.input.feed_size'])
# Out:
# KstestResult(statistic=0.05922065470904381, pvalue=3.5273935105512727e-12)

# %% [markdown]
# **Вывод:**
# - из графиков видно, что распределение и на стадии флотации и на стадии первичной отчистки выглядят нормальным распеределением.
# - на стадии флотации - распределения отличаются чуть больше - видно смещение тренировочной выборки чуть больше вправо. В то время как на стадии первичной отчистки - практически совпадают.
# - по усам видно, что в данных наблюдаются явные аномалии и выбросы - будем с ними работать.
#
# **Таким образом, можно сказать, что не наблюдается значимых различий между распределениями для выборок.**
#
# Интересен тот факт, что примернение теста Колмогорова-Смирнова показала:
# - что на стадии флотации группы по рассмотренному признаку отличаются существенно (`pvalue` значительно ниже 5%).
# - на стадии же финальной отчистки - ситуация значительно улучшается в разы. Но тем не менее также `pvalue` не достаточно высока.
# > Считаю, что причина в наличии у признаков аномалий, которые мы явно увидели при построении "усов" диаграмы рассеяния.

# %% [markdown]
# ### **Исследуем суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.**
#
# - Вычислим суммарную концентрацию всех элементов на каждом этапе.
# - Будем иссследовать на аномальные значения в суммарном распределении (Если они есть, проверим - стоит ли их удалять из обеих выборок?)
# - Опишием выводы и удалим аномалии.

# %%
#Напишем функцию рассчета суммарной концентрации всех элементов на каждом этапе (используем тренировочную выборку)
def sum_concentrate(data_train, name_state):
    sum_concentrate = 0
    for metal in ['au', 'ag', 'pb', 'sol']:
        sum_concentrate += data_train[f'{name_state}_{metal}']
    return sum_concentrate

# %%
#Вычислим суммарную концентрацию всех элементов на этапе флотации сырья
sum_concentrate_rougher_input = sum_concentrate(data_train, 'rougher.input.feed')
(sum_concentrate_rougher_input.median()).round(2)
# Out:
# 56.63

# %%
#Вычислим суммарную концентрацию всех элементов на этапе флотации продукта
sum_concentrate_rougher_output = sum_concentrate(data_train, 'rougher.output.concentrate')
(sum_concentrate_rougher_output.median()).round(2)
# Out:
# 69.18

# %%
#Вычислим суммарную концентрацию всех элементов на этапе первичной очистки продукта
sum_primary_cleaner_output = sum_concentrate(data_train, 'primary_cleaner.output.concentrate')
(sum_primary_cleaner_output.median()).round(2)
# Out:
# 61.79

# %%
#Вычислим суммарную концентрацию всех элементов на финальном этапе
sum_concentrate_final_output = sum_concentrate(data_train, 'final.output.concentrate')
(sum_concentrate_final_output.median()).round(2)
# Out:
# 69.14

# %%
#Построим диаграмму распределения
plt.figure(figsize=[20, 10])
    #plt.subplots_adjust(top=0.94, wspace=0.2, hspace=0.3)
    #plt.suptitle('График концентрации всех элементов на различных этапах очистки', fontsize=15)
plt.title(f'Гистограмма распределения суммарной концентрации всех элементов на различных этапах очистки', fontsize=18)
sns.set_style('whitegrid')
sns.histplot(sum_concentrate_rougher_input, color="deepskyblue", label='Сырье', alpha=0.7, kde=True)
sns.histplot(sum_concentrate_rougher_output, color="salmon", label=f'Концентрация элементов после флотации', alpha=0.7, kde=True)
sns.histplot(sum_primary_cleaner_output, color="seagreen", label=f'Концентрация элементов после первичной очистки', alpha=0.7, kde=True)
sns.histplot(sum_concentrate_final_output, color="gold", label=f'Финальная концетрация элементов', alpha=0.7, kde=True)
plt.xlabel(f'Концентрация всех элементов', fontsize=14)
plt.ylabel(f'Количество наблюдений', fontsize=14)
plt.legend(loc='upper left', fontsize='large')

# %%
plt.subplots(figsize=(20, 5))
plt.title(f'Скрипичная диаграмма рассеяния суммарной концентрации всех элементов на различных этапах очистки')
sns.violinplot(x=sum_concentrate_rougher_input, palette='pastel', data=sum_concentrate_rougher_input)
sns.violinplot(x=sum_concentrate_rougher_output, color="salmon", data=sum_concentrate_rougher_output)
sns.violinplot(x=sum_primary_cleaner_output, color="seagreen", data=sum_primary_cleaner_output)
sns.violinplot(x=sum_concentrate_final_output, color="gold", data=sum_concentrate_final_output)
plt.show()

# %%
plt.subplots(figsize=(15, 3))
plt.title(f'Диаграмма рассеяния суммарной концентрации всех элементов на различных этапах очистки')
sns.boxplot(x=sum_concentrate_rougher_input, palette='pastel', data=sum_concentrate_rougher_input)
plt.show()
plt.subplots(figsize=(15, 3))
sns.boxplot(x=sum_concentrate_rougher_output, color="salmon", data=sum_concentrate_rougher_output)
plt.show()
plt.subplots(figsize=(15, 3))
sns.boxplot(x=sum_primary_cleaner_output, color="seagreen", data=sum_primary_cleaner_output)
plt.show()
plt.subplots(figsize=(15, 3))
sns.boxplot(x=sum_concentrate_final_output, color="gold", data=sum_concentrate_final_output)
plt.show()

# %%
sum_concentrate_rougher_input.describe()
# Out:
# count   14,149.00
# mean        56.24
# std          7.03
# min          0.04
# 25%         52.57
# 50%         56.63
# 75%         60.76
# max         74.46
# Name: rougher.input.feed_au, dtype: float64

# %%
sum_concentrate_rougher_output.describe()
# Out:
# count   14,149.00
# mean        67.17
# std         12.71
# min          0.00
# 25%         64.91
# 50%         69.18
# 75%         73.43
# max         88.14
# Name: rougher.output.concentrate_au, dtype: float64

# %%
sum_concentrate_final_output.describe()
# Out:
# count   14,149.00
# mean        68.39
# std          7.02
# min          0.00
# 25%         67.56
# 50%         69.14
# 75%         70.97
# max         80.21
# Name: final.output.concentrate_au, dtype: float64

# %%
data_full_best = data_full[(data_full['rougher.output.concentrate_au'] != 0)\
                  & (data_full['rougher.output.concentrate_ag'] != 0)\
                  & (data_full['rougher.output.concentrate_pb'] != 0)\
                  & (data_full['rougher.output.concentrate_sol'] != 0)\
                  & (data_full['final.output.concentrate_au'] != 0)\
                  & (data_full['final.output.concentrate_ag'] != 0)\
                  & (data_full['final.output.concentrate_pb'] != 0)\
                  & (data_full['final.output.concentrate_sol'] != 0)]
data_train_best = data_train[(data_train['rougher.output.concentrate_au'] != 0)\
                    & (data_train['rougher.output.concentrate_ag'] != 0)\
                    & (data_train['rougher.output.concentrate_pb'] != 0)\
                    & (data_train['rougher.output.concentrate_sol'] != 0)\
                    & (data_train['final.output.concentrate_au'] != 0)\
                    & (data_train['final.output.concentrate_ag'] != 0)\
                    & (data_train['final.output.concentrate_pb'] != 0)\
                    & (data_train['final.output.concentrate_sol'] != 0)]

# %%
#проверим
#data_train[(data_train['final.output.concentrate_au'] == 0)]
data_train_best[(data_train_best['final.output.concentrate_au'] == 0)]
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# **Вывод:**
# - в целом суммарное распределение элементов нормальное по всем стадиям;
# - наблюдается явные выбросы на всех этапах в районе 0: и по скрипичной диаграмме, и по диаграмме рассеяния.
# > Посчитала нужным удалить эти выбросы, чтобы они не мешали в дальнейшем работать с моделью (и в тренировочной выборке, и в исходных данных)

# %% [markdown]
# ## Модель
# Постройте модель

# %% [markdown]
# ### **Напишите функцию для вычисления итоговой sMAPE.**
# Симметричная средняя абсолютная процентная ошибка (SMAPE) (используется для измерения прогностической точности моделей)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def smape (target, predictions):
    smape = 100*np.sum(2*np.abs(target - predictions)/(np.abs(target) + np.abs(predictions)))/len(target)
    return smape

# %%
def smape_sum(target_rouger, pred_rougher, target_final, pred_final):
    rougher = smape(target_rouger, pred_rougher)
    final = smape(target_final, pred_final)
    #smape_summary = 0.25*rougher + 0.75*final
    return rougher, final

def smape_summary(rougher, final):
  return 0.25*rougher + 0.75*final

# %% [markdown]
# ### **Обучите разные модели и оцените их качество кросс-валидацией**
#
# - Подготовим данные для модели.
# - Выберем лучшую модель и проверим её на тестовой выборке.
# - Опишем выводы.
# > Пригодятся формулы метрик качества

# %%
#подготовим данные для модели
#удалим из обучающей выборки те признаки, которых нет в тестовой
train_best = data_train_best.drop(set(data_train_best.columns)-set(data_test.columns), axis=1)
#data_train_without_target = data_nottest - set(['rougher.output.recovery','final.output.recovery'])
#train_best = data_train_best.drop(columns=sdata_train_without_target, axis=1)

# %%
#подготовим ОБУЧАЮЩУЮ выборку по признакам и целям (этапа флотации и финального этапа)
features_train = train_best.drop(['rougher.output.recovery','final.output.recovery'], axis=1)
target_train_rougher = train_best['rougher.output.recovery']
target_train_final = train_best['final.output.recovery']

# %%
#подготовим ТЕСТОВУЮ выборку по признакам и целям (этапа флотации и финального этапа)
features_test = data_test.drop(['rougher.output.recovery','final.output.recovery'], axis=1)
target_test_rougher = data_test['rougher.output.recovery']
target_test_final = data_test['final.output.recovery']

# %%
#Проверим выборки
print('Размер обучающей выборки по признакам:', features_train.shape)
print('Размер обучающей выборки по целям (этапа флотации):', target_train_rougher.shape)
print('Размер обучающей выборки по целям (финального этапа):', target_train_final.shape)
print('Размер тестовой выборки по признакам:',features_test.shape)
print('Размер тестовой выборки по целям (этапа флотации):', target_test_rougher.shape)
print('Размер тестовой выборки по целям (финального этапа):', target_test_final.shape)
# Out:
# Размер обучающей выборки по признакам: (13792, 52)
# Размер обучающей выборки по целям (этапа флотации): (13792,)
# Размер обучающей выборки по целям (финального этапа): (13792,)
# Размер тестовой выборки по признакам: (5290, 52)
# Размер тестовой выборки по целям (этапа флотации): (5290,)
# Размер тестовой выборки по целям (финального этапа): (5290,)

# %%
# Подбор параметров модели с помощью make_scorer из sklearn.metrics
smape_score = make_scorer(smape, greater_is_better= False)

# %%
#создадим кортеж для записи в него sMAPE наших моделей
data_scores = {}

# %% [markdown]
# **Модель Дерева решений (DecisionTreeRegressor)**
# - исследуем глубину max_depth
# - проведем кросс-валидацию

# %%
state = RandomState(12345)

# %%
def model_dtr(features_train, target_train, state):
    model_dtr = DecisionTreeRegressor(random_state=12345)
    parametrs = {'max_depth': range(1, 20)} #, 'class_weight':['balanced']
    grid_dtr = GridSearchCV(model_dtr, parametrs, cv=5, scoring = smape_score) #, n_jobs=-1)
    grid_dtr.fit(features_train, target_train)
    return grid_dtr

# %%
# %%time
grid_dtr_rougher = model_dtr(features_train, target_train_rougher, 'rougher')
# Out:
# CPU times: user 49.8 s, sys: 147 ms, total: 50 s
# Wall time: 50 s

# %%
# %%time
grid_dtr_final = model_dtr(features_train, target_train_final, 'final')
# Out:
# CPU times: user 50.8 s, sys: 99.2 ms, total: 50.9 s
# Wall time: 52.9 s

# %%
print(f'На стадии флотации {grid_dtr_rougher.best_params_}')
print(f'Симметричная средняя абсолютная процентная ошибка на стадии флотации')
print(f'sMAPE_rougher = {abs(round(grid_dtr_rougher.best_score_, 3))}(взяли по модулю)')

print(f'\nНа финальной стадии{grid_dtr_final.best_params_}')
print(f'Симметричная средняя абсолютная процентная ошибка на финальной стадии')
print(f'sMAPE_final = {abs(round(grid_dtr_final.best_score_, 3))}(взяли по модулю)')
# Out:
# На стадии флотации {'max_depth': 3}
# Симметричная средняя абсолютная процентная ошибка на стадии флотации
# sMAPE_rougher = 7.356(взяли по модулю)
#
# На финальной стадии{'max_depth': 2}
# Симметричная средняя абсолютная процентная ошибка на финальной стадии
# sMAPE_final = 9.383(взяли по модулю)

# %%
summary_smape_dtr = smape_summary(grid_dtr_rougher.best_score_, grid_dtr_final.best_score_)*(-1)
data_scores['dtr'] = [summary_smape_dtr]
data_scores['dtr']
# Out:
# [8.876099353367739]

# %% [markdown]
# **Модель Логической регрессии (LinearRegression)**

# %%
# %%time
model_rougher_lr = LinearRegression()
smape_rougher = cross_val_score(model_rougher_lr, features_train, target_train_rougher,
                          scoring=smape_score, cv=5)
model_final_lr = LinearRegression()
smape_final = cross_val_score(model_final_lr, features_train, target_train_final,
                          scoring=smape_score, cv=5)
summary_smape = smape_summary(smape_rougher.mean(), smape_final.mean())*(-1)
data_scores['lr'] = [summary_smape]
data_scores['lr']
# Out:
# CPU times: user 916 ms, sys: 1.77 s, total: 2.69 s
# Wall time: 2.7 s
# [10.0592614434828]

# %% [markdown]
# **Модель Cлучайный лес (RandomForestRegressor)**
#
# Применим функцию GridSearchCV для проверки параметров модели

# %%
def model_rfc(features_train, target_train, state):
    model_rfc = RandomForestRegressor(random_state=12345)
    parametrs = {'max_depth': range (1,10,2),'n_estimators': range (10, 40, 5),
                 'min_samples_leaf': range (1,3)} #'min_samples_split': range (1,8), 'criterion': ['entropy', None], 'class_weight':['balanced']
    grid_rfc = GridSearchCV(model_rfc, parametrs, cv=5, scoring = smape_score) #, n_jobs=-1)
    grid_rfc.fit(features_train, target_train)
    return grid_rfc

# %%
# %%time
grid_rfc_rougher = model_rfc(features_train, target_train_rougher, 'rougher')
# Out:
# CPU times: user 20min 32s, sys: 2.46 s, total: 20min 34s
# Wall time: 20min 35s

# %%
# %%time
grid_rfc_final = model_rfc(features_train, target_train_final, 'final')
# Out:
# CPU times: user 20min 41s, sys: 2.83 s, total: 20min 44s
# Wall time: 20min 45s

# %%
print(f'На стадии флотации лучшие параметры: {grid_rfc_rougher.best_params_}')
print(f'Симметричная средняя абсолютная процентная ошибка на стадии флотации')
print(f'sMAPE_rougher = {abs(round(grid_rfc_rougher.best_score_, 3))}(взяли по модулю)')

print(f'\nНа финальной стадии{grid_rfc_final.best_params_}')
print(f'Симметричная средняя абсолютная процентная ошибка на финальной стадии')
print(f'sMAPE_final = {abs(round(grid_rfc_final.best_score_, 3))}(взяли по модулю)')
# Out:
# На стадии флотации лучшие параметры: {'max_depth': 5, 'min_samples_leaf': 1, 'n_estimators': 10}
# Симметричная средняя абсолютная процентная ошибка на стадии флотации
# sMAPE_rougher = 6.648(взяли по модулю)
#
# На финальной стадии{'max_depth': 3, 'min_samples_leaf': 1, 'n_estimators': 35}
# Симметричная средняя абсолютная процентная ошибка на финальной стадии
# sMAPE_final = 9.205(взяли по модулю)

# %%
summary_smape_rfc = smape_summary(grid_rfc_rougher.best_score_, grid_rfc_final.best_score_)*(-1)
data_scores['rfc'] = [summary_smape_rfc]
data_scores
# Out:
# {'dtr': [8.876099353367739],
#  'lr': [10.0592614434828],
#  'rfc': [8.5658634831351]}

# %% [markdown]
# **Вывод:**
# - Исследование показало, что лучшей моделью является Случайный лес **sMAPE_sum = 8.567**
# > немного от него отстает по показателям Дерево решений.
#
# Возьмем для тестовой выборки - **модель случайного леса** со следующими лучшими параметрами :
#   - для стадии флотации:
#     - 'max_depth': 5,
#     - 'min_samples_leaf': 1
#     - 'n_estimators': 10
#   - для финальной стадии
#     - 'max_depth': 3,
#     - 'min_samples_leaf': 1
#     - 'n_estimators': 35

# %%
model_test_rougher = RandomForestRegressor(min_samples_leaf=1, max_depth=5, n_estimators = 10, random_state=state)
model_test_rougher.fit(features_train, target_train_rougher)
predictions_rougher = model_test_rougher.predict(features_test)

model_test_final = RandomForestRegressor(min_samples_leaf=1, max_depth=3, n_estimators = 35, random_state=state)
model_test_final.fit(features_train, target_train_final)
predictions_final = model_test_final.predict(features_test)

smape_test_rougher = smape (target_test_rougher, predictions_rougher)
smape_test_final = smape (target_test_final, predictions_final)
summary_smape_test = smape_summary(smape_test_rougher, smape_test_final)

# %%
print('Итоговая оценка sMAPE на тестовой выборке составляет:', round(summary_smape_test, 2))
# Out:
# Итоговая оценка sMAPE на тестовой выборке составляет: 9.13

# %% [markdown]
# **Проверим модель на адекватность**
# > Вычислим показатель `sMAPE` для константной модели и сравним с результатами нашей лучшей модели.

# %%
dummy_rougher = DummyRegressor(strategy="mean")
dummy_final = DummyRegressor(strategy="mean")

dummy_rougher.fit(features_train, target_train_rougher)
dummy_final.fit(features_train, target_train_final)

dummy_predictions_rougher = dummy_rougher.predict(features_test)
dummy_predictions_final = dummy_final.predict(features_test)

smape_rougher_const = smape (target_test_rougher, dummy_predictions_rougher)
smape_final_const = smape (target_test_final, dummy_predictions_final)
summary_smape_const = smape_summary(smape_rougher_const, smape_final_const)

# %%
print('Итоговая оценка sMAPE на константной модели составляет:', round(summary_smape_const, 2))
# Out:
# Итоговая оценка sMAPE на константной модели составляет: 9.82

# %% [markdown]
# Вывод:
# - Проверила на адекватность модели - показатель sMAPE на константной модели значительно выше по сравнению с нашей учшей модели - следовательно наша модель хорошего качества

# %% [markdown]
# ## **Вывод:**
# - Данные исследованы, проведена их предобработка:
#   - явных дубликатов не найдено,
#   - пропуски заменены соседними данными,
#   - проведена проверка расчетов эффективности обогащения - все верно.
#   - проанализированы признаки недоступные в тестовой выборке.
#   - добавлены целевые признаки `rougher.output.recovery `и `final.output.recovery` - в дальнейшем их использовала для расчета метрик качества.
#   - удалены неинформативные для построения модели столбцы - `data`.
# - Проведен детальный анализ данных, построены диаграммы:
#   - из графиков видно,концентрация металлов соответствует нормальному распределению.
#   - распределение по всем параметрам  и на стадии флотации, и на стадии первичной отчистки также выглядят нормальным распеределением, как и суммарное распределение элементов нормальное по всем основным стадиям.
#    > на стадии флотации - распределения отличаются чуть больше - видно смещение тренировочной выборки чуть больше вправо. В то время как на стадии первичной отчистки - практически совпадают.
#   - по усам диаграммы рассеяния и по скрипичной диаграмме выявлены явные аномалии и выбросы, особенно в районе 0 - удалила их, чтобы они не мешали в дальнейшем работать с моделью (и в тренировочной выборке, и в исходных данных).
# - Обучено 3 модели:
#   - Модель Дерева решений (DecisionTreeRegressor);
#   - Модель Логической регрессии (LinearRegression);
#   - Модель Cлучайный лес (RandomForestRegressor).
# - Оценка качества проведена методом кросс-валидациии - по итогу выбрана **лучшая модель Cлучайный лес (RandomForestRegressor) sMAPE_sum = 8.567**. Параметры лучшей модели:
#   - на обучающей выборке:
#     - для стадии флотации:
#     - 'max_depth': 5,
#     - 'min_samples_leaf': 1
#     - 'n_estimators': 10
#     - sMAPE_rougher = 6.654
#   - для финальной стадии
#     - 'max_depth': 3,
#     - 'min_samples_leaf': 1
#     - 'n_estimators': 35
#     - sMAPE_final = 9.205
#   - на тестовой выборке:
# - Проверка на адекватность модели показала, что выбранная нами модель хорошего качества:
#    - на константной модели sMAPE =  9.82;
#    - **на тестовой выборке нашей модели sMAPE = 9.13**.
